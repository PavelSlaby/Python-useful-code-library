# %% [markdown]
# # Numbers in Python

# %%
b = 0.35
c = 0.5

b + 0.1
# Out:
# 0.44999999999999996

# %%
c.as_integer_ratio(), b.as_integer_ratio()  # 15 digit relative accuracy
# Out:
# ((1, 2), (3152519739159347, 9007199254740992))

# %%
# To increase accuracy, use decimal module
import decimal
from decimal import Decimal

decimal.getcontext?
# Out:
# Signature: decimal.getcontext()
# Docstring: Get the current default context.
# Type:      builtin_function_or_method

# %%
# Python itself runs on use the IEEE 754 double-precision standard — i.e., 64 bits   15 digit relative accuracy
decimal.getcontext().prec = 153
Decimal(b) + Decimal(0.1)
# Out:
# Decimal('0.4499999999999999833466546306226518936455249786376953125')

# %%
decimal.getcontext()  # default precision is 28, can be changed, see below
# Out:
# Context(prec=153, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[FloatOperation], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
1 / 11, Decimal(1) / Decimal(11)
# Out:
# (0.09090909090909091,
#  Decimal('0.0909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909090909'))

# %%
z = -87.7e100
z
# Out:
# -8.77e+101

# %%
x = 1j
x
# Out:
# 1j

# %%
int(z)
# Out:
# -876999999999999953141299176594128207296085227481859399976488364482518445137613994205637190836616691712

# %%
float(10)
# Out:
# 10.0

# %%
int(10.9)
# Out:
# 10

# %%
int("1598")
# Out:
# 1598

# %%
int(True), int(False), float(True), bool(0), oct(10), hex(10)
# Out:
# (1, 0, 1.0, False, '0o12', '0xa')

# %%
float('nan')
# Out:
# nan

# %%
import random
random.randrange(1, 3)  # random number between 1 and 2 excluding the last number
# Out:
# 2

# %% [markdown]
# ## Numerical operations

# %%
15 // 7  # floor division, rounds down automatically
# Out:
# 2

# %%
x = 0
x =+ 5
x
# Out:
# 5

# %%
x += 5
x
# Out:
# 10

# %%
x -= 4
x
# Out:
# 6

# %%
x *= 10
x
# Out:
# 60

# %%
x /= 10
x
# Out:
# 6.0

# %%
x **= 3
x
# Out:
# 216.0

# %%
8 % 7 # modulo
# Out:
# 1

# %%
2 ** 2
# Out:
# 4

# %%
3 == 3
# Out:
# True

# %%
min([3,4])
# Out:
# 3

# %%
pow(3, 3)  # power
# Out:
# 27

# %%
abs(-5)
# Out:
# 5
