# %% [markdown]
# # Math module

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.degrees(math.pi)
# Out:
# 180.0

# %%
math.exp(1), math.exp(1) == math.e
# Out:
# (2.718281828459045, True)

# %%
math.inf  # returns infinity
# Out:
# inf

# %%
math.factorial(4)
# Out:
# 24

# %%
math.floor(24.2264654)
# Out:
# 24

# %%
math.ceil(24.2264654)
# Out:
# 25

# %%
math.log(math.exp(1))
# Out:
# 1.0

# %%
math.log(27)
# Out:
# 3.295836866004329

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.sin(1), math.tau
# Out:
# (0.8414709848078965, 6.283185307179586)

# %%
math.fabs(-5.5) # returns absolute number as a float
# Out:
# 5.5

# %%
math.nan, math.nan == math.nan
# Out:
# (nan, False)
