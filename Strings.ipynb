# %% [markdown]
# ## Strings

# %%
t = 'this is a string on one row'

# %%
t2 = '''this is 
a string 
over several rows
'''

# %%
print(t2)
print(t)
# Out:
# this is
# a string
# over several rows
#
# this is a string on one row

# %%
t.split(" ")
# Out:
# ['this', 'is', 'a', 'string', 'on', 'one', 'row']

# %%
t.split("a")
# Out:
# ['this is ', ' string on one row']

# %%
t.capitalize()
# Out:
# 'This is a string on one row'

# %%
t.upper()
# Out:
# 'THIS IS A STRING ON ONE ROW'

# %%
t.lower()
# Out:
# 'this is a string on one row'

# %%
" Hello, World!           ".strip()
# Out:
# 'Hello, World!'

# %%
t.endswith('g')
# Out:
# False

# %%
t.index('t')
# Out:
# 0

# %%
t.count('s')
# Out:
# 3

# %%
t.replace('s', 'cat', 2) #replaces first 2 appereances of s with cat
# Out:
# 'thicat icat a string on one row'

# %%
t.find(' ')
# Out:
# 4

# %%
t.find('wx') # returns -1 if there is none
# Out:
# -1
